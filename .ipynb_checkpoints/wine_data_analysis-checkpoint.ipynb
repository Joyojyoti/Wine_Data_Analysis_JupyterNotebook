# %%
import pandas as pd
df_white = pd.read_csv('winequality-white.csv', sep=';')
df_red = pd.read_csv('winequality-red.csv', sep=';')

# %%
df_white.shape
# Out:
# (4898, 12)

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
df_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
sum(df_white.duplicated())
# Out:
# 937

# %%
len(df_red['quality'].unique().tolist())
# Out:
# 6

# %%
len(df_white['quality'].unique().tolist())
# Out:
# 7

# %%
import numpy as np
np.mean(df_red['density'])
# Out:
# 0.9967466791744833

# %%
color_red = 'red'
color_white = 'white'

# %%
df_red['color'] = color_red
df_white['color'] = color_white

# %%
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df_combined = df_red.append(df_white, ignore_index=True)

# %%
df_combined
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# ...

# %%
df_combined.rename(index=str, columns={"total sulfur dioxide":"total_sulfur_dioxide"})
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# ...

# %%
# %matplotlib inline
df_combined.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D5B1448B70>,
# ...
#       dtype=object)

# %%
df_combined.plot('quality','volatile acidity',figsize=(15,10))

# %%
df_combined.plot('quality','residual sugar',figsize=(15,10))

# %%
df_combined.plot('quality','pH',figsize=(15,10))

# %%
df_combined.plot('quality','alcohol',figsize=(15,10))

# %%
df_combined.to_csv('whole_dataset.csv', index=False)

# %%
import pandas as pd
df_wine = pd.read_csv('whole_dataset.csv')
df_wine.shape
# Out:
# (6497, 13)

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %%
df_wine.groupby('color')['quality'].mean()
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
binedges = [2.72,3.11,3.21,3.32,4.01]
binnames = ['Low','Medium','Moderately high','High']

# %%
df_wine['acidity_levels']= pd.cut(df_wine['pH'],binedges, labels=binnames)

# %%
df_wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color   acidity_levels
# 0      9.4        5   red             High
# ...

# %%
df_wine.to_csv('whole_dataset.csv', index=False)

# %%
df_wine['acidity_levels'].describe()
# Out:
# count     6496
# unique       4
# top        Low
# freq      1717
# Name: acidity_levels, dtype: object

# %%
import pandas as pd
df_wine = pd.read_csv('whole_dataset.csv')
df_wine.shape
# Out:
# (6497, 14)

# %%
df_wine['alcohol'].median()
# Out:
# 10.3

# %%
low_alcohol = df_wine.query('alcohol < 10.3')
high_alcohol = df_wine.query('alcohol >= 10.3')

# %%
num_samples = df_wine.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# True

# %%
low_alcohol['quality'].mean()
# Out:
# 5.475920679886686

# %%
high_alcohol['quality'].mean()
# Out:
# 6.146084337349397

# %%
df_wine['residual sugar'].median()
# Out:
# 3.0

# %%
low_sugar = df_wine[df_wine['residual sugar'] < 3.0]
high_sugar = df_wine[df_wine['residual sugar'] >= 3.0]

# %%
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count()
# Out:
# True

# %%
low_sugar['quality'].mean()
# Out:
# 5.808800743724822

# %%
high_sugar['quality'].mean()
# Out:
# 5.82782874617737

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('whole_dataset.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color   acidity_levels
# 0      9.4        5   red             High
# ...

# %%
df.groupby('color')['quality'].mean().plot(kind='bar', title='Quality Level by Color', color=['red','pink'] ,alpha=.7)
plt.xlabel('Colours', fontsize=18)
plt.ylabel('Quality', fontsize=18)
# Out:
# Text(0, 0.5, 'Quality')

# %%
counts = df.groupby(['quality','color']).count()['pH']
counts.plot(kind='bar', title='Count by Quality and colour', color=['red','pink'] ,figsize=(10,8))
plt.xlabel('Colours and Quality', fontsize=18)
plt.ylabel('Counts', fontsize=18)
# Out:
# Text(0, 0.5, 'Counts')

# %%
totals = df.groupby('color').count()['pH']
proportion = counts / totals
proportion.plot(kind='bar', title='Proportion by Quality and colour', color=['red','pink'] ,alpha=.7,figsize=(10,8))
plt.xlabel('Colours and Quality', fontsize=18)
plt.ylabel('Proportion', fontsize=18)
# Out:
# Text(0, 0.5, 'Proportion')

# %%
"""In some more convenient way"""
# Out:
# 'In some more convenient way'

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('whole_dataset.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color   acidity_levels
# 0      9.4        5   red             High
# ...

# %%
median = df['alcohol'].median()
low = df.query('alcohol < {}'.format(median))
high = df.query('alcohol >= {}'.format(median))

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
locations = [1,2]
heights = [mean_quality_low, mean_quality_high]
labels = ['Low','High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Alcohol content')
plt.xlabel('Alcohol Content',fontsize=15)
plt.ylabel('Average Quality Rating',fontsize=15)
# Out:
# Text(0, 0.5, 'Average Quality Rating')

# %%
median = df['residual sugar'].median()
low = df[df['residual sugar'] < median]
high = df[df['residual sugar'] >= median]

mean_quality_low = low['quality'].mean()
mean_quality_high = high['quality'].mean()

# %%
locations = [1,2]
heights = [mean_quality_low, mean_quality_high]
labels = ['Low','High']
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Sugar content')
plt.xlabel('Sugar Content',fontsize=15)
plt.ylabel('Average Quality Rating',fontsize=15)
# Out:
# Text(0, 0.5, 'Average Quality Rating')

# %%
mean_acidity_level = df.groupby('acidity_levels').mean()['quality']
mean_acidity_level
# Out:
# acidity_levels
# High               5.859593
# Low                5.783343
# Medium             5.784540
# Moderately high    5.850832
# Name: quality, dtype: float64

# %%
locations = [4,1,2,3]
heights = mean_acidity_level
labels = ['Low','Medium','Moderately High','High']
#labels = mean_acidity_level.index.str.replace('_', ' ').str.title()
plt.bar(locations, heights, tick_label=labels)
plt.title('Average Quality Ratings by Acidity Levels')
plt.xlabel('Acidity Levels',fontsize=15)
plt.ylabel('Average Quality Rating',fontsize=15)
# Out:
# Text(0, 0.5, 'Average Quality Rating')
